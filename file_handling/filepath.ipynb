# %%
import os
print(os.getcwd())
# Out:
# c:\Users\KASHISH\Desktop\ML\file_handling

# %%
new_directory='package'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' is created")
# Out:
# Directory 'package' is created

# %%
items=os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'fileop.ipynb', 'filepath.ipynb', 'package']

# %%
dir_name='folder'
file_name='file.txt'
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\KASHISH\Desktop\ML\file_handling\folder\file.txt

# %%
path='example.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"the path '{path}' does not exist")
# Out:
# The path 'example.txt' exists

# %%
path='example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory")
else:
    print("Niether a file nor a directory")
# Out:
# The path 'example.txt' is a file

# %%
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\KASHISH\Desktop\ML\file_handling\example.txt
