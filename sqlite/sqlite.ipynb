# %%
import sqlite3

# %%
connection=sqlite3.connect('example.db')

# %%
connection

# %%
cursor=connection.cursor()

# %%
cursor.execute('''
Create table if not exists employee(
               id Integer Primary Key,
               name Text Not Null,
                age Integer,
               department text
               )
''')
connection.commit()

# %%
cursor.execute(
    '''
Insert Into Employee(name,age,department)
values('Krish',32,'Data Science')
'''
)
connection.commit()

# %%
cursor.execute(
    '''
Insert Into Employee(name,age,department)
values('Bob',32,'Cs')
'''
)
cursor.execute(
    '''
Insert Into Employee(name,age,department)
values('Charles',32,'Finance')
'''
)
connection.commit()

# %%
cursor.execute('''
    Select * from Employee
''')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Krish', 32, 'Data Science')
# (2, 'Bob', 32, 'Cs')
# (3, 'Charles', 32, 'Finance')

# %%
cursor.execute('''
    Update Employee
               Set age=34
               Where name='Krish'
''')
connection.commit()

# %%
cursor.execute('''
    Select * from Employee
''')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cursor.execute('''
#       2     Select * from Employee
#       3 ''')
#       4 rows=cursor.fetchall()
#       5 for row in rows:
#
# ProgrammingError: Cannot operate on a closed database.

# %%
connection.close()

# %%
cursor.execute('''
    Delete from Employee
               where name='Krish'
''')

# %%
connection=sqlite3.connect('Sales_data.db')
cursor=connection.cursor()

# %%
cursor.execute('''
    Create table if not exists Sales(
               id Integer Primary key,
               date text not null,
               product text not null,
               sales integer,
               region text
               )
''')
connection.commit()

# %%
sales_data=[
    ('2023-01-01','p1',100,'North'),
    ('2023-01-01','p2',100,'South'),
    ('2023-01-01','p3',100,'North'),
    ('2023-01-01','p4',100,'East'),
    ('2023-01-01','p5',100,'West')
]

# %%
cursor.executemany('''
    Insert into Sales(date,product,sales,region)
                   values(?,?,?,?)
''',sales_data)
connection.commit()

# %%
cursor.execute('''
    Select * from Sales
''')
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'p1', 100, 'North')
# (2, '2023-01-01', 'p2', 100, 'South')
# (3, '2023-01-01', 'p3', 100, 'North')
# (4, '2023-01-01', 'p4', 100, 'East')
# (5, '2023-01-01', 'p5', 100, 'West')

# %%
connection.commit()
