# %%
# !pip install NLTK
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: NLTK in c:\users\kashish\appdata\roaming\python\python312\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\kashish\appdata\roaming\python\python312\site-packages (from NLTK) (8.3.1)
# Requirement already satisfied: joblib in c:\users\kashish\appdata\roaming\python\python312\site-packages (from NLTK) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kashish\appdata\roaming\python\python312\site-packages (from NLTK) (2026.2.19)
# Requirement already satisfied: tqdm in c:\users\kashish\appdata\roaming\python\python312\site-packages (from NLTK) (4.67.3)
# Requirement already satisfied: colorama in c:\users\kashish\appdata\roaming\python\python312\site-packages (from click->NLTK) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus = """Hello Welcome,to Krish Naik's NLP tutorial.
Please do watch the entire course! To become expert in NLP."""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP tutorial.
# Please do watch the entire course! To become expert in NLP.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\KASHISH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\KASHISH\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
print(documents)
# Out:
# ["Hello Welcome,to Krish Naik's NLP tutorial.", 'Please do watch the entire course!', 'To become expert in NLP.']

# %%
from nltk.tokenize import word_tokenize
word_tokenize()
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorial',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'To',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'tutorial', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['To', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'tutorial',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'To',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorial.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'To',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
