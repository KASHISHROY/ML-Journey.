# %%
def welcome():
    return "Welcome to the course"
print(welcome())
wel=welcome
wel()
print(wel())
del welcome
print(wel())
# Out:
# Welcome to the course
# Welcome to the course
# Welcome to the course

# %%
def main_welcome():
    msg="Welcome"
    def sum_welcome_method():
        print("Welcome to the course")
        print(msg)
        print("This is nice course!")
    return sum_welcome_method()
main_welcome()
# Out:
# Welcome to the course
# Welcome
# This is nice course!

# %%
def main_welcome(fun):
    msg="Welcome"
    def sum_welcome_method():
        print("Welcome to the course")
        fun(msg)
        print("This is nice course!")
    return sum_welcome_method()
main_welcome(print)
# Out:
# Welcome to the course
# Welcome
# This is nice course!

# %%
def main_welcome(fun,list):
    msg="Welcome"
    def sum_welcome_method():
        print("Welcome to the course")
        print(msg)
        print(fun(list))
        print("This is nice course!")
    return sum_welcome_method()
main_welcome(len,[1,2,3,4,5])
# Out:
# Welcome to the course
# Welcome
# 5
# This is nice course!

# %%
def main_welcome(fun):
    msg="Welcome"
    def sum_welcome_method():
        print("Welcome to the course")
        print(msg)
        fun()
        print("This is nice course!")
    return sum_welcome_method()

# %%
@main_welcome
def course_intro():
    print("This is an amazing course")
# Out:
# Welcome to the course
# Welcome
# This is an amazing course
# This is nice course!

# %%
course_intro()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 course_intro()
#
# TypeError: 'NoneType' object is not callable
