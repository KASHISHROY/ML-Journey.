# %%
my_list=[1,2,3,4,5,6]
for i in my_list:
    print(i)
print(my_list)
print(type(my_list))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# [1, 2, 3, 4, 5, 6]
# <class 'list'>

# %%
iterator=iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
print(iterator)

# %%
print(next(iterator))

# %%
try:
    print(next(iterator))
except StopIteration:
    print("There is no element in iteraror")
# Out:
# There is no element in iteraror

# %%
my_string="hello"
string_iterator=iter(my_string)
print(next(string_iterator))
print(next(string_iterator))
# Out:
# h
# e
