# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
series=pd.Series(data)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
series=pd.Series(data,index=index)
print(series)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data={
    'Name':['Krish','John','Jack'],
    'Age':[20,30,40],
    'City':['Bangalore','New York','Florida']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
df
# Out:
#     Name  Age       City
# 0  Krish   20  Bangalore
# 1   John   30   New York
# 2   Jack   40    Florida
# <class 'pandas.core.frame.DataFrame'>
#     Name  Age       City
# 0  Krish   20  Bangalore
# 1   John   30   New York
# 2   Jack   40    Florida

# %%
import numpy as np
print(np.array(df))
# Out:
# [['Krish' 20 'Bangalore']
#  ['John' 30 'New York']
#  ['Jack' 40 'Florida']]

# %%
df['Name']
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.head(2)
df.tail(1)
# Out:
#    Name  Age     City
# 2  Jack   40  Florida

# %%
df.loc[0]
# Out:
# Name        Krish
# Age            20
# City    Bangalore
# Name: 0, dtype: object

# %%
df.iloc[0][0]
# Out:
# C:\Users\KASHISH\AppData\Local\Temp\ipykernel_9532\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'Krish'

# %%
df.iloc[0]
# Out:
# Name        Krish
# Age            20
# City    Bangalore
# Name: 0, dtype: object

# %%
df.iloc[0][2]
# Out:
# C:\Users\KASHISH\AppData\Local\Temp\ipykernel_9532\2519637664.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# 'Bangalore'

# %%
print(df.at[1,'Age'])
print(df.at[2,'Name'])
print(df.iat[2,2])
# Out:
# 30
# Jack
# Florida

# %%
df['Salary']=[500000,600000,700000]
df
# Out:
#     Name  Age       City  Salary
# 0  Krish   20  Bangalore  500000
# 1   John   30   New York  600000
# 2   Jack   40    Florida  700000

# %%
df.drop('Salary',axis=1)
# Out:
#     Name  Age       City
# 0  Krish   20  Bangalore
# 1   John   30   New York
# 2   Jack   40    Florida

# %%
df
# Out:
#     Name  Age       City  Salary
# 0  Krish   20  Bangalore  500000
# 1   John   30   New York  600000
# 2   Jack   40    Florida  700000

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#    Name  Age      City
# 1  John   31  New York
# 2  Jack   41   Florida

# %%
df.dtypes
df.describe()
# Out:
#              Age
# count   2.000000
# mean   36.000000
# std     7.071068
# min    31.000000
# 25%    33.500000
# 50%    36.000000
# 75%    38.500000
# max    41.000000

# %%
df.drop(0,inplace=True)

# %%
df['Age']=df['Age']+1
